# %%
import pandas as pd

# %%
p1="/home/au761367/codes/lepinet/data/global/0032836-250426092105405_processing_metadata_postprocessed_quality_filtered.parquet"
d1=pd.read_parquet(p1)

p2="/home/au761367/codes/lepinet/data/small/0032836-250426092105405_processing_metadata_postprocessed_quality_filtered.lepinet.parquet"
d2=pd.read_parquet(p2)

# %%
d1.columns, d2.columns

# %%
d2.image_path.iloc[0]

# %%
"https://anon.erda.au.dk/share_redirect/On0rdRltgS/global_lepi/images/1801896/6c3887194368830950e1edd51e096ae1509e7fb7.jpg"
